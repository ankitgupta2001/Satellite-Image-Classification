# %% [markdown]
# # Land Cover Classification using Deep Learning Techniques and EuroSAT

# %% [markdown]
# ## Mounting google drive for dataset access and saving models

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls gdrive/MyDrive
# Out:
# '185533 (1).pdf'
# '185533 (2).pdf'
# '185533 (3).pdf'
# '185533 (4).pdf'
# '185533 Ada.pdf'
# '185533 CD Assignment (1).pdf'
# '185533 CD Assignment.pdf'
# '185533 CD.pdf'
# '185533 CE.pdf'
# '185533 Dbms mid sem.pdf'
# '185533 MAS Test.pdf'
# '185533 NN.pdf'
#  185533.pdf
# '185533 - Resume'
#  185533.zip
# 'Ada 185533.pdf'
# 'Anand Kumar (185533).pdf'
# 'Anand'\''s Resume (185533).pdf'
# 'Behaviour Assignment.gdoc'
#  Classroom
# 'Colab Notebooks'
# 'Computer Networks Lab Final Assignment .gdoc'
# 'DBMS LAB 1 (185533).docx'
# 'DBMS LAB 2 (185533).pdf'
# 'DBMS LAB 3 (185533).pdf'
# 'DBMS LAB 4 (185533).pdf'
# 'DBMS LAB 5 - 6 (185533).pdf'
#  Demo_Outlook_Account_Gen.mp4
# 'dwt-zsuu-ywk - Sep 21, 2021.gjam'
# 'Edited - 185533csd320(1).pdf'
# 'Edited - 185533csd320.pdf'
#  Image_Dataset.zip
# 'Information Security Lab (185533).gdoc'
# 'Information Security Lab (185533).pdf'
# 'Information Security Lab Assignment 2 (185533).pdf'
# 'Information Security Lab Assignment 3 (185533).gdoc'
# 'Information Security Lab Assignment 3 (185533).pdf'
# 'Information Security Lab Assignment 5 (185533).pdf'
# 'Information Security Lab (Lab 1).gdoc'
# 'Information Security Lab (Lab 2).gdoc'
# 'Information Security Report 185533.gdoc'
# 'LBP Modification.gdoc'
# 'Major Project Report.gdoc'
# 'Modelling Test 185533.pdf'
#  OpenAstronomy.gslides
#  Report.gdoc
# 'Report Group 9.pdf'
# 'SATELLITE IMAGE CLASSIFICATION USING CONVOLUTIONAL NEURAL NETWORK.gdoc'
# 'Soft Computing Assignment (185533).gdoc'
# 'Untitled document.gdoc'
#  vlcsnap-2020-07-22-18h27m53s303.png

# %%
# !unzip gdrive/MyDrive/Image_Dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Image_Dataset/SeaLake/SeaLake_2827.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1418.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1816.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_671.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1360.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_50.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2154.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1820.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2650.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2596.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1931.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_607.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2114.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1812.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1653.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1995.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2329.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1415.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_618.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1197.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1280.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2601.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1929.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_616.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1642.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_857.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1645.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2835.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1300.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1492.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_623.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1838.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_786.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_849.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_498.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2481.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_951.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2933.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_304.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_130.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2559.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1494.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_128.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1676.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2473.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2103.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2562.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2337.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_662.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1636.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1342.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_936.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2479.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_654.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_867.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1497.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2259.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1801.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_855.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1647.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2100.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2676.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2262.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1862.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1656.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2593.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1205.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1663.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2319.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2151.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2180.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2843.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2967.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2836.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1130.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_164.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_502.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2106.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2630.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2478.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1039.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_149.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2008.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2531.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1352.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2181.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2938.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_259.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_513.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2820.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2978.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_430.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_86.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1549.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2535.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2940.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1730.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1742.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_253.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1666.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1200.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1483.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2741.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1654.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_
jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_443.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_396.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_89.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_264.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_218.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2123.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2007.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2124.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_952.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_920.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2187.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_258.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2414.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1488.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2009.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2108.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1193.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_357.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1800.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2567.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_866.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_942.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_930.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_299.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_771.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2983.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2190.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_937.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2995.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1799.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2538.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_2595.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1278.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1204.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_1858.jpg
#   inflating: Image_Dataset/SeaLake/SeaLake_604.jpg
# ...
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2473.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_110.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2253.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1306.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2236.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2231.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2243.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2182.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2077.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1364.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1621.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1628.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_985.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_982.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1538.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1584.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_88.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_979.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_206.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1670.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_977.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2068.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_410.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_82.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_321.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_328.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_339.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2006.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2247.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_497.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1880.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1818.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1947.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_226.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1681.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_42.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_873.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1441.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1104.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2259.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2288.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2257.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_480.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_907.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_824.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2172.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1370.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_153.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1640.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2107.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2100.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_706.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1368.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_875.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_762.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1862.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2091.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2096.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2187.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_269.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2468.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2075.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2466.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2299.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1036.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_896.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1450.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1776.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1461.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1593.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2294.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2242.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_431.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1100.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1023.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2379.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_275.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2377.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_200.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2067.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2171.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1301.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_87.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1582.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2369.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1820.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_494.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_755.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1427.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_692.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_470.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1298.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_246.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1307.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1529.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_81.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2102.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1694.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2054.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_322.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_163.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_164.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_505.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_237.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1891.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1898.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1674.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1673.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2074.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1244.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1238.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1549.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1367.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2301.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2080.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_416.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_43.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_898.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_832.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1594.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1813.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_146.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_98.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1866.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_332.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_504.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2302.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1442.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1784.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_11.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_324.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1631.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2104.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1034.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1420.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1938.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_695.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1770.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1815.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1766.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_994.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_542.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1679.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1677.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1025.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_242.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1923.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_53.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1252.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1951.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_66.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1166.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_801.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_647.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2389.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2429.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_856.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2011.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_734.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1716.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1988.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1078.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_255.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_648.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1990.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1044.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1413.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_728.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2419.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1175.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_117.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1928.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_938.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_943.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_346.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_73.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_172.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1041.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2416.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2423.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2424.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_196.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_792.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2013.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_862.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1918.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_450.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1170.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_735.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_79.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_104.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2318.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2380.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1416.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1077.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1949.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_253.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_797.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_949.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2023.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_598.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_947.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2381.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_563.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_199.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_289.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_340.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1219.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1954.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_232.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_80.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_341.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1073.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_288.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1412.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_526.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_281.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_530.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1223.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1133.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1256.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1983.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1141.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1929.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1955.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2139.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1174.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_658.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_462.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_857.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_789.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1079.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1917.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1171.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1266.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_456.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_596.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1228.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_74.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_554.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1081.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_1050.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_854.jpg
#   inflating: Image_Dataset/PermanentCrop/PermanentCrop_2014.jpg

# %% [markdown]
# ## Libraries

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm
from tqdm.notebook import tqdm
import seaborn as sns


from sklearn.metrics import confusion_matrix
from sklearn import model_selection

import torch
import torchvision.models as models
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision.transforms import transforms
from torchvision.utils import make_grid
import torch.nn.functional as F

# %% [markdown]
# ## Config

# %%
ROOT_PATH = os.getcwd()
BASE_PATH = os.path.join(ROOT_PATH, 'Image_Dataset')
DATA_PATH = os.path.join(ROOT_PATH, 'Dataset')
FULL_DATA_DF = os.path.join(ROOT_PATH, 'FULL_DATA.csv')

if not os.path.isdir(DATA_PATH):
    os.mkdir(DATA_PATH)

IDX_CLASS_LABELS = {
    0: 'AnnualCrop',
    1: 'Forest', 
    2: 'HerbaceousVegetation',
    3: 'Highway',
    4: 'Industrial',
    5: 'Pasture',
    6: 'PermanentCrop',
    7: 'Residential',
    8: 'River',
    9: 'SeaLake'
}
CLASSES = ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture','PermanentCrop','Residential','River', 'SeaLake']
CLASS_IDX_LABELS = dict()
for key, val in IDX_CLASS_LABELS.items():
    CLASS_IDX_LABELS[val] = key

NUM_CLASSES = len(IDX_CLASS_LABELS.items())
torch.manual_seed(10)
VALID_SIZE = 0.1

# %%
ROOT_PATH
print(torch.cuda.is_available())
# Out:
# True

# %%
CLASS_IDX_LABELS
# Out:
# {'AnnualCrop': 0,
#  'Forest': 1,
#  'HerbaceousVegetation': 2,
#  'Highway': 3,
#  'Industrial': 4,
#  'Pasture': 5,
#  'PermanentCrop': 6,
#  'Residential': 7,
#  'River': 8,
#  'SeaLake': 9}

# %% [markdown]
# ## Utils

# %%
## Give idx of each class name
def encode_label(label):
    idx = CLASS_IDX_LABELS[label] 
    return idx

## Take in idx and return the class name
def decode_target(target, text_labels=True):
    result = []
    if text_labels:
        return IDX_CLASS_LABELS[target]
    else:
        return target

## Show batches of images
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize=(16, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=16).permute(1, 2, 0))
        break

# %%
## Example for decoding and encoding
print(encode_label('Forest'), decode_target(2))
print(decode_target(2, text_labels=True))
# Out:
# 1 HerbaceousVegetation
# HerbaceousVegetation

# %% [markdown]
# ## Pre-Processing data folders to train and test
# Run this code cells only if you don't have the required dataframe

# %%
from os import walk
i = 0
for (dirpath, dirname, filename) in walk(BASE_PATH):
    print("Directory Path: ", dirpath)
    print("Directory Name: ", dirname)
    print("Filename : ", filename)
    print("----------------------"*10)
    i += 1
    if i > 1:
        break
# Out:
# Directory Path:  /content/Image_Dataset
# Directory Name:  ['Pasture', 'PermanentCrop', 'AnnualCrop', 'Highway', 'SeaLake', 'River', 'HerbaceousVegetation', 'Industrial', 'Residential', 'Forest']
# Filename :  []
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Directory Path:  /content/Image_Dataset/Pasture
# Directory Name:  []
# Filename :  ['Pasture_1944.jpg', 'Pasture_85.jpg', 'Pasture_1449.jpg', 'Pasture_414.jpg', 'Pasture_1004.jpg', 'Pasture_1104.jpg', 'Pasture_1582.jpg', 'Pasture_456.jpg', 'Pasture_647.jpg', 'Pasture_479.jpg', 'Pasture_1950.jpg', 'Pasture_1982.jpg', 'Pasture_1340.jpg', 'Pasture_1033.jpg', 'Pasture_286.jpg', 'Pasture_1099.jpg', 'Pasture_677.jpg', 'Pasture_409.jpg', 'Pasture_1762.jpg', 'Pasture_1519.jpg', 'Pasture_1276.jpg', 'Pasture_1502.jpg', 'Pasture_1174.jpg', 'Pasture_133.jpg', 'Pasture_753.jpg', 'Pasture_269.jpg', 'Pasture_149.jpg', 'Pasture_1268.jpg', 'Pasture_613.jpg', 'Pasture_632.jpg', 'Pasture_765.jpg', 'Pasture_707.jpg', 'Pasture_464.jpg', 'Pasture_1209.jpg', 'Pasture_1506.jpg', 'P
ture_432.jpg', 'Pasture_1781.jpg', 'Pasture_447.jpg', 'Pasture_360.jpg', 'Pasture_1766.jpg', 'Pasture_977.jpg', 'Pasture_1910.jpg', 'Pasture_1771.jpg', 'Pasture_824.jpg', 'Pasture_1329.jpg', 'Pasture_300.jpg', 'Pasture_482.jpg', 'Pasture_1061.jpg', 'Pasture_1324.jpg', 'Pasture_840.jpg', 'Pasture_378.jpg', 'Pasture_1291.jpg', 'Pasture_1225.jpg', 'Pasture_760.jpg', 'Pasture_1607.jpg', 'Pasture_846.jpg', 'Pasture_1328.jpg', 'Pasture_1653.jpg', 'Pasture_1150.jpg', 'Pasture_940.jpg', 'Pasture_713.jpg', 'Pasture_708.jpg', 'Pasture_1353.jpg', 'Pasture_1678.jpg', 'Pasture_356.jpg', 'Pasture_44.jpg', 'Pasture_699.jpg', 'Pasture_527.jpg', 'Pasture_1795.jpg', 'Pasture_1954.jpg', 'Pasture_1739.jpg', 'Pasture_1498.jpg', 'Pasture_1666.jpg', 'Pasture_505.jpg', 'Pasture_679.jpg', 'Pasture_122.jpg', 'Pasture_943.jpg', 'Pasture_1301.jpg', 'Pasture_1337.jpg', 'Pasture_1946.jpg', 'Pasture_1559.jpg', 'Pasture_119.jpg', 'Pasture_2000.jpg', 'Pasture_1094.jpg', 'Pasture_490.jpg', 'Pasture_1757.jpg', 'Pasture_1986.jpg', 'Pasture_182.jpg', 'Pasture_1576.jpg', 'Pasture_880.jpg', 'Pasture_948.jpg', 'Pasture_1155.jpg', 'Pasture_1426.jpg', 'Pasture ...
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
from os import walk

i = 0
DATA_DF = pd.DataFrame(columns = ['image_id', 'label'], dtype=object) 

for (dirpath, dirname, filename) in walk(BASE_PATH):
    for each_file in filename:
        DATA_DF.loc[i] = [each_file, dirpath.split('/')[-1]]
        i += 1
        # break
DATA_DF.to_csv(FULL_DATA_DF, index=False)
DATA_DF.head()
# Out:
#            image_id    label
# 0  Pasture_1944.jpg  Pasture
# 1    Pasture_85.jpg  Pasture
# 2  Pasture_1449.jpg  Pasture
# 3   Pasture_414.jpg  Pasture
# 4  Pasture_1004.jpg  Pasture

# %% [markdown]
# ## Processing data folders to train and test

# %%
DATA_DF = pd.read_csv(FULL_DATA_DF)
DATA_DF = DATA_DF.sample(frac = 1, random_state=48) 
TRAIN_DF = DATA_DF[:-int(len(DATA_DF)*VALID_SIZE)]
VALID_DF = DATA_DF[-int(len(DATA_DF)*VALID_SIZE) :]

# %%
TRAIN_DF.reset_index(inplace = True) 
TRAIN_DF.head()
# Out:
#    index                       image_id                 label
# 0  19127            Industrial_1121.jpg            Industrial
# 1   3197         PermanentCrop_1053.jpg         PermanentCrop
# 2  24557                 Forest_711.jpg                Forest
# 3  17042  HerbaceousVegetation_1039.jpg  HerbaceousVegetation
# 4   3697          PermanentCrop_651.jpg         PermanentCrop

# %%
VALID_DF.reset_index(inplace = True) 
VALID_DF.head()
# Out:
#    index             image_id        label
# 0  21985  Residential_327.jpg  Residential
# 1  25621      Forest_1253.jpg       Forest
# 2  21573  Residential_534.jpg  Residential
# 3  25070      Forest_2225.jpg       Forest
# 4  13947       River_1225.jpg        River

# %%
TRAIN_DF.size, VALID_DF.size
# Out:
# (72900, 8100)

# %% [markdown]
# ## Creating Dataset and Dataloaders
#
# Now we will Create custom dataset by extending pytorch Dataset class. We also add provision for adding transformers for data augmentation.

# %%
class EuroSAT(Dataset):
    def __init__(self, train_df, train_dir, transform=None):
        self.train_dir = train_dir
        self.train_df = train_df
        self.transform = transform
        
    def __len__(self):
        return len(self.train_df)
    
    def __getitem__(self, idx):
        row = self.train_df.loc[idx]
        img_id, label = row['image_id'], row['label']
        img = Image.open(os.path.join(self.train_dir, img_id.split('.')[0].split('_')[0], img_id))
        if self.transform:
            img = self.transform(img)
        return img, encode_label(label)

# %% [markdown]
# ### Transformations and Datasets

# %%
## Dataset and transformations
data_transform = transforms.Compose([
                                transforms.Resize(size=(224, 224)),
#                                 transforms.CenterCrop(224),
                                transforms.ToTensor(),
                                # transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                ])
train_ds = EuroSAT(TRAIN_DF, BASE_PATH, data_transform)
valid_ds = EuroSAT(VALID_DF, BASE_PATH, data_transform)
print(len(train_ds), len(valid_ds))
# Out:
# 24300 2700

# %%
## Data loaders and showing batch of data
batch_size = 64
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=2, pin_memory=True)
valid_dl = DataLoader(valid_ds, batch_size, shuffle=False, num_workers=2, pin_memory=True)
show_batch(train_dl)

# %% [markdown]
# ## Model

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim = 1)
    return torch.tensor(torch.sum(preds==labels).item() / len(preds))

class MulticlassClassifierBase(nn.Module):
    
    def training_step(self, batch):
        img, label = batch
        out = self(img)
        loss = criterion(out, label)
        accu = accuracy(out, label)
        return accu ,loss
    def validation_step(self, batch):
        img, label = batch
        out = self(img)
        loss = criterion(out, label)
        accu = accuracy(out, label)
        return {"val_loss": loss.detach(), "val_acc": accu}
    
    def validation_epoch_ends(self, outputs):
        batch_loss = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_loss).mean()
        batch_acc = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_acc).mean()
        return {"val_loss":epoch_loss.item(), "val_acc":epoch_acc.item()}
    def epoch_end(self, epoch, result):
        print("Epoch [{}],train_accu: {:.4f}, learning_rate: {:.4f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch,result['train_accu'], result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_acc']))

# %%
class LULC_Model(MulticlassClassifierBase):
    def __init__(self):
        super().__init__()
        self.network = models.wide_resnet50_2(pretrained=True)
        n_inputs = self.network.fc.in_features
        self.network.fc = nn.Sequential(
                              nn.Linear(n_inputs, 256),
                              nn.ReLU(),
                              nn.Dropout(0.5),
                              nn.Linear(256, NUM_CLASSES),
                              nn.LogSoftmax(dim=1)
                                )
    def forward(self, xb):
        return self.network(xb)
    
    def freeze(self):
        for param in self.network.parameters():
            param.require_grad=False
        for param in self.network.fc.parameters():
            param.require_grad=True
    def unfreeze(self):
        for param in self.network.parameters():
            param.require_grad=True

# %%
model = LULC_Model()
# Out:
# Downloading: "https://download.pytorch.org/models/wide_resnet50_2-95faca4d.pth" to /root/.cache/torch/hub/checkpoints/wide_resnet50_2-95faca4d.pth
#   0%|          | 0.00/132M [00:00<?, ?B/s]

# %%
## Running through the data loader => Model => Output
def try_batch(dl):
    for images, labels in dl:  
        print(images.shape)
        out = model(images)
        print(out.shape)
        print(out[0])
        break
try_batch(train_dl)
# Out:
# torch.Size([64, 3, 224, 224])
# torch.Size([64, 10])
# tensor([-2.4710, -2.3706, -2.5106, -2.0749, -2.3350, -2.1098, -1.9959, -2.4485,
#         -2.5083, -2.3699], grad_fn=<SelectBackward0>)

# %% [markdown]
# ## Training and Evaluating

# %%
@torch.no_grad()
def evaluate(model, valid_loader):
    model.eval()
    outputs = [model.validation_step(batch) for batch in valid_loader]
    return model.validation_epoch_ends(outputs)

def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
    
def fit(epochs, max_lr,  model, train_loader, valid_loader, weight_decay=0,\
                grad_clip=None,opt_func=torch.optim.SGD, max_epochs_stop=3):
  
    history = []
    valid_loss_min = np.Inf
    valid_acc_max = 0
    model_file_name = 'lulc.pth'
    model_file_name2 = 'lulc_max_acc.pth'
    epochs_no_improve =  0
    optimizer = opt_func(model.parameters(), lr=max_lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.00001)
                         
    for epoch in range(epochs):
        model.train()
        train_loss = []
        train_accu = []
        lrs = []
        for batch in tqdm(train_loader):
            
            accu, loss = model.training_step(batch)
            train_loss.append(loss)
            train_accu.append(accu)
            loss.backward()
            ## Gradient Clipping
            if grad_clip:
                nn.utils.clip_grad_value_(model.parameters(), grad_clip)
            
            optimizer.step()
            optimizer.zero_grad()
            
            lrs.append(get_lr(optimizer))
            
            
            
        result = evaluate(model, valid_loader)
        scheduler.step(result['val_loss'])
        ########### Early Stopping ##############                                         
        valid_loss = result['val_loss']
        valid_acc = result['val_acc']
        if valid_acc > valid_acc_max:
            torch.save(model.state_dict(), model_file_name2)
            valid_acc_max = valid_acc
        if valid_loss<valid_loss_min:
            torch.save(model.state_dict(), model_file_name)
            valid_loss_min = valid_loss                                  
            epochs_no_improve = 0          
        else:
            epochs_no_improve += 1
            if epochs_no_improve > max_epochs_stop:
                result["train_loss"] = torch.stack(train_loss).mean().item()
                result["train_accu"] = torch.stack(train_accu).mean().item()
                result["lrs"] = lrs
                model.epoch_end(epoch, result)
                history.append(result)
                print("Early Stopping............................")
                return history                                
                                                 
        result["train_loss"] = torch.stack(train_loss).mean().item()
        result["train_accu"] = torch.stack(train_accu).mean().item()
        result["lrs"] = lrs
        model.epoch_end(epoch, result)
        history.append(result)
    print("VAL LOSS MIN {}".format(valid_loss_min))
    print("VAL ACC MAX {}".format(valid_acc_max))
    return history

# %% [markdown]
# ## Initializing Device also Loading Data and Model to device¶

# %%
def get_device():
    print(torch.cuda.is_available())
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        for b in self.dl:
            yield to_device(b, self.device)
            
    def __len__(self):
        return len(self.dl)

# %%
device = get_device()
## Loading data to devide
train_dl = DeviceDataLoader(train_dl, device)
valid_dl = DeviceDataLoader(valid_dl, device)
## Loading model to device
model = to_device(LULC_Model(), device)
## lets try passing a batch to model again
try_batch(train_dl)
# Out:
# True
# torch.Size([64, 3, 224, 224])
# torch.Size([64, 10])
# tensor([-2.3598, -2.2277, -2.1588, -2.2402, -2.4023, -2.2145, -2.3377, -2.3850,
#         -2.5076, -2.2439], device='cuda:0', grad_fn=<SelectBackward0>)

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Training

# %%
## Hyper Parameters
max_epochs_stop = 10
max_lr = 1e-4
grad_clip = 0.1
weight_decay = 1e-3
batch_size = 64
criterion = nn.CrossEntropyLoss()
epochs = 10
opt_func = torch.optim.Adam
## Evaluating with non-trained model
evaluate(model, valid_dl)
# Out:
# {'val_acc': 0.10307655483484268, 'val_loss': 2.306993007659912}

# %%
## Freezing except last layer
model.freeze()
## Training
history = fit(epochs, max_lr, model, train_dl, valid_dl, weight_decay, grad_clip, opt_func, max_epochs_stop)
# Out:
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [0],train_accu: 0.9252, learning_rate: 0.0001, train_loss: 0.2836, val_loss: 0.0843, val_acc: 0.9717
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [1],train_accu: 0.9643, learning_rate: 0.0001, train_loss: 0.1151, val_loss: 0.0802, val_acc: 0.9702
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [2],train_accu: 0.9744, learning_rate: 0.0001, train_loss: 0.0859, val_loss: 0.0887, val_acc: 0.9675
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [3],train_accu: 0.9755, learning_rate: 0.0001, train_loss: 0.0816, val_loss: 0.1096, val_acc: 0.9648
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [4],train_accu: 0.9771, learning_rate: 0.0001, train_loss: 0.0784, val_loss: 0.0928, val_acc: 0.9677
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [5],train_accu: 0.9773, learning_rate: 0.0000, train_loss: 0.0732, val_loss: 0.0796, val_acc: 0.9727
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [6],train_accu: 0.9781, learning_rate: 0.0000, train_loss: 0.0713, val_loss: 0.0767, val_acc: 0.9746
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [7],train_accu: 0.9769, learning_rate: 0.0000, train_loss: 0.0747, val_loss: 0.0710, val_acc: 0.9775
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [8],train_accu: 0.9782, learning_rate: 0.0000, train_loss: 0.0730, val_loss: 0.0770, val_acc: 0.9742
#   0%|          | 0/380 [00:00<?, ?it/s]
# Epoch [9],train_accu: 0.9789, learning_rate: 0.0000, train_loss: 0.0702, val_loss: 0.0829, val_acc: 0.9727
# VAL LOSS MIN 0.07099087536334991
# VAL ACC MAX 0.9774709343910217

# %% [markdown]
# ## Reports

# %% [markdown]
# ### Training Reports

# %%
def plot_losses(history):
    train_losses = [x.get('train_loss') for x in history]
    val_losses = [x['val_loss'] for x in history]
    plt.plot(train_losses, '-bx')
    plt.plot(val_losses, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.legend(['Training', 'Validation'])
    plt.title('Loss vs. No. of epochs');
    
plot_losses(history)

# %%
def plot_accuracy(history):
        
    train_accu = [x.get('train_accu') for x in history]
    val_accu = [x['val_acc'] for x in history]
    plt.plot(train_accu, '-bx')
    plt.plot(val_accu, '-rx')
    plt.xlabel('epoch')
    plt.ylabel('Accuracy')
    plt.legend(['Training', 'Validation'])
    plt.title('Accuracy vs. No. of epochs');
plot_accuracy(history)

# %%
def plot_lrs(history):
    lrs = np.concatenate([x.get('lrs', []) for x in history])
    plt.plot(lrs)
    plt.xlabel('Batch no.')
    plt.ylabel('Learning rate')
    plt.title('Learning Rate vs. Batch no.');
    
plot_lrs(history)

# %% [markdown]
# ### Prediction Reports

# %%
def show_sample(img, target=None):
    if target:
        print("Label" ,decode_target(int(target), text_labels=True))
    plt.imshow(img.permute(1, 2, 0))

### Predict Single Images
def predict_single(image):
    show_sample(image)
    xb = image.unsqueeze(0)
    xb = to_device(xb, device)
    preds = model(xb)
    _, prediction = torch.max(preds.cpu().detach(), dim=1)
    return decode_target(int(prediction), text_labels=True)

# %%
predict_single(valid_ds[40][0])
# Out:
# 'HerbaceousVegetation'

# %%
predict_single(valid_ds[30][0])
# Out:
# 'Highway'

# %%
predict_single(valid_ds[90][0])
# Out:
# 'River'

# %% [markdown]
# ## Evaluation on whole dataset

# %%
batch_size =1
@torch.no_grad()
def predict_dl(dl, model):
    torch.cuda.empty_cache()
    batch_pred, labels = [], []
    for xb, label in tqdm(dl):
        probs = model(xb)
        _, pred = torch.max(probs.cpu().detach(), dim=1)
        batch_pred.append(pred.cpu().detach())     
        labels.append(label)   
    return [x for x in batch_pred], \
            [x for x in labels]

# %%
## Accuracy Evaluation
def final_accuracy(predictions, labels):
  predictions = to_device(predictions, device)
  labels = to_device(labels, device)
  ## Total Accuracy
  total = 0
  for i in range(len(predictions)):
    if predictions[i] == labels[i]:
      total += 1
  acc = total/len(predictions)
  print(acc)

# %%
full_ds = EuroSAT(DATA_DF, BASE_PATH, data_transform)
full_dl = DataLoader(full_ds, batch_size, shuffle=True, num_workers=0, pin_memory=True)
device = get_device()
## Loading data to devide
full_dl = DeviceDataLoader(full_dl, device)
# Out:
# True

# %%
predictions, labels = predict_dl(full_dl, model)
final_accuracy(predictions, labels)
preds = [x.item() for x in predictions]
labs = [x.item() for x in labels]
cm = confusion_matrix(preds, labs)
cm
# Out:
#   0%|          | 0/27000 [00:00<?, ?it/s]
# 0.9877037037037038
# array([[2972,    0,   14,    0,    0,    8,   27,    0,    5,    0],
#        [   0, 2969,    0,    0,    0,    0,    0,    0,    1,    0],
#        [   0,    2, 2943,    0,    0,    3,   13,    0,   17,    0],
#        [   3,    0,    1, 2499,   46,    0,    6,    6,   48,    0],
#        [   0,    0,    1,    0, 2447,    0,    0,    2,    1,    0],
#        [   1,    2,   22,    0,    0, 1988,    8,    0,    8,    0],
#        [   9,    0,    6,    0,    0,    0, 2441,    0,    0,    0],
#        [   0,    0,    0,    0,    6,    0,    4, 2992,    0,    0],
#        [   7,    0,    0,    1,    1,    0,    0,    0, 2417,    0],
#        [   8,   27,   13,    0,    0,    1,    1,    0,    3, 3000]])

# %%
## Plotting Confusion matrix
df_cm = pd.DataFrame(cm, CLASSES, CLASSES)
sns.set(font_scale=1.4) # for label size
plt.figure(figsize = (16,6))
sns.heatmap(df_cm, annot=True)

# %%
## Evaluation with best validation accuracy model
model = LULC_Model()
model.load_state_dict(torch.load("/content/lulc_max_acc.pth"))
model.eval()
model = to_device(model, device)
predictions, labels = predict_dl(full_dl, model)
final_accuracy(predictions, labels)
preds = [x.item() for x in predictions]
labs = [x.item() for x in labels]
cm = confusion_matrix(preds, labs)
cm
# Out:
#   0%|          | 0/27000 [00:00<?, ?it/s]
# 0.9901111111111112
# array([[2963,    0,   10,    0,    0,    7,   23,    0,    4,    0],
#        [   1, 2993,    1,    0,    0,    0,    1,    0,    2,    0],
#        [   0,    2, 2949,    0,    0,    3,   16,    0,   17,    0],
#        [   3,    0,    1, 2499,   25,    0,    5,    5,   32,    0],
#        [   0,    0,    1,    0, 2470,    0,    0,    2,    1,    0],
#        [   1,    0,   25,    0,    0, 1990,    8,    0,   10,    0],
#        [   9,    0,    5,    0,    0,    0, 2445,    0,    0,    0],
#        [   0,    0,    0,    0,    4,    0,    1, 2993,    0,    0],
#        [  16,    0,    0,    1,    1,    0,    0,    0, 2431,    0],
#        [   7,    5,    8,    0,    0,    0,    1,    0,    3, 3000]])

# %%
## Plotting Confusion matrix
df_cm = pd.DataFrame(cm, CLASSES, CLASSES)
sns.set(font_scale=1.4) # for label size
plt.figure(figsize = (16,6))
sns.heatmap(df_cm, annot=True)
